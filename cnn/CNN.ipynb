# %%
from IPython.display import Image
Image(filename='conv00.png', width=600)

# %%
from IPython.display import Image
Image(filename='conv01.png', width=600)

# %%
from IPython.display import Image
Image(filename='pool00.png', width=600)

# %%
from IPython.display import Image
Image(filename='im2col.png', width=600)

# %%
from IPython.display import Image
Image(filename='pooling.png', width=600)

# %%
from IPython.display import Image
Image(filename='simple_cnn.png', width=600)
